# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/smarter-way-to-learn-python/blob/main/24_Nov_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## chp1 Print

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ##chp2 Variables

# %%
# spaces should not be given in 'variable' names
my name = "Hamza"
print(my name)
# Out:
#   File "/tmp/ipython-input-254410331.py", line 2
#     my name = "Hamza"
#        ^
# SyntaxError: invalid syntax

# %%
my_name = "Hamza"
name1 = "Omer"
name2 = "Usman"
print(my_name, name1, name2)
# Out:
# Hamza Omer Usman

# %%
# 'Variable' name matter nhi krta kuch bhi rakha jaa sakta hai, mgr call bhi us exactname se krna hoga
flooo = "whatever"
print(flooo)
# Out:
# whatever

# %% [markdown]
# ## chp3 Variables(nums)

# %%
RAM = "16"
print(RAM)
# Out:
# 16

# %%
#RAM in current state is the data type: 'string' due to the use of (""), to validate the command it is neccesary to change the data type of the variable(RAM) to int to make the command work
print(RAM + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3280927581.py in <cell line: 0>()
#       1 #RAM in current state is the data type: 'string', to validate the command it is neccesary to change the data type of the variable(RAM) to int to make the command work
# ----> 2 print(RAM + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(int(RAM) + 5)
# Out:
# 21

# %%
#in the following command; the variable(new_num) has been assigned to the answer:233, ab agr kahin bhi call krna hoga to us naam se hi krna hoga
number1 = 175
number2 = 58
new_num = int(number1) + int(number2)
print(new_num)
# Out:
# 233

# %%
#now the data type will automatically indentify data type (int)
num1 = 75
num2 = 25
total = num1 + num2
print(total)
# Out:
# 100

# %% [markdown]
# ## chp4 Variables(Math expressions: Familiar operators)

# %%
random_num = (1548 + 66) * 3
print(random_num)
# Out:
# 4842

# %%
random_num = (1548 + 66) * 3
random_num1 = (789 + 54) * 3/4
most_random_num = (random_num + random_num1)
print(most_random_num)
# Out:
# 5474.25

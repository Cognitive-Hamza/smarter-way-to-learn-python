# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/smarter-way-to-learn-python/blob/main/30_Dec_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## chp 35 How to pick information out of a list of dictionaries

# %%
customer_29876 = {
"first name": "David",
"last name": "Elliott",
"address": "4803 Wellesley St.",
 }

# %%
customers = [
    {
        "customer_id": 0,
        "first_name": "Jahanzaib",
        "last name": "Ali",
        "address": "Scheme 45",
    },
    {
        "customer_id": 1,
        "first_name": "Omer",
        "last_name": "Khan",
        "address": "Scheme 33",
    },
    {
        "customer_id": 2,
        "first_name": "Wasif",
        "last_name": "Hussain",
        "address": "North Nazimabad",
    }
]

# %%
customer_first_name = customer_29876["first name"]
print(customer_first_name)
# Out:
# David

# %%
dictionary_to_look_in = customers[2]
customer2_address = dictionary_to_look_in["address"]
print(customer2_address)
# Out:
# North Nazimabad

# %% [markdown]
# ##chp36 How to append a new dictionary to a list of dictionaries

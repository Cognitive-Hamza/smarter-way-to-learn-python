# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/smarter-way-to-learn-python/blob/main/6_Jan_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##chp46 Functions: Dealing with an unknown number of arguments

# %%
def display_result(winner, score):
  print("The winner was " + winner)
  print("The score was " + score)
display_result(winner="Real Madrid", score="1-0")
# Out:
# The winner was Real Madrid
# The score was 1-0

# %% [markdown]
# But suppose there are times when you want to display other information about the match—but not always. For example, you call the same function and include these optional arguments:

# %%
display_result(winner="Real Madrid", score="1-0", overtime ="yes", injuries="none")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2459060893.py in <cell line: 0>()
# ----> 1 display_result(winner="Real Madrid", score="1-0", overtime ="yes", injuries="none")
#
# TypeError: display_result() got an unexpected keyword argument 'overtime'

# %% [markdown]
# error showed up ⏫

# %%
#The function can handle optional arguments with this code:
def display_result(winner, score, **other_info):
  #here the important part are the 2 stars i can also write 'whatever' instead of other_info
  print("The winner was " + winner)
  print("The score was " + score)
  for key, value in other_info.items():
    print(key + ": " + value)

display_result(winner="Real Madrid", score="1-0", overtime ="yes", injuries="none")
# Out:
# The winner was Real Madrid
# The score was 1-0
# overtime: yes
# injuries: none

# %%
#Positional arguments can be optional as well. To handle optional positional arguments, you use a single asterisk:
def display_nums(first_num, second_num, *opt_nums):
  print(first_num)
  print(second_num)
  print(opt_nums)

display_nums(100, 200, 300, 400, 500)
#here 100 goes into the parameter first_num, 200 goes into the parameter second_num, and the last three numbers, the optional arguments, go into the parameter *opt_nums.

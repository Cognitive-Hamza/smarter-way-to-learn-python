# %% [markdown]
# <a href="https://colab.research.google.com/github/Cognitive-Hamza/smarter-way-to-learn-python/blob/main/1_Jan_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##chp41 Fuctions

# %% [markdown]
# A function is a block of Python code that robotically does the same thing again and again, whenever you invoke its name. It saves you repetitive coding and makes your code easier to understand

# %%
# Here the function is named "add_numbers", so whenever we call the function it will then show up/do its functions.
def add_numbers():
  first_number = 29
  second_number = 31
  total = first_number + second_number
  print(total)
add_numbers()
# Out:
# 60

# %% [markdown]
# ##chp42 Functions: Passing them information

# %% [markdown]
# If you put some information inside the parentheses, that information is passed to the function. The function can then use the information when it executes.

# %%
# Suppose, instead of writing add_numbers() you write... add_numbers(53, 108)
def add_numbers(first_number, second_number):
  total = first_number + second_number
  print(total)
add_numbers(53, 108)
'''The arguments in the function call the numbers 53 and 109 are the information that's passed to the function by the code that calls the function.
The parameters inside the parentheses in the function definition—first_number and second_number—catch the data that's passed.'''
# Out:
# 161

# %%
def greet_user(greeting):
  print(greeting)
  greeting = "Hello, dunya!"
greet_user(greeting)
# Out:
# Hello, dunya!

# %% [markdown]
# ##chp43 Functions: Passing information to them a different way

# %%
husband_name = "Bill"
wife_name = "Zelda"
def say_names_of_couple(husband_name, wife_name):
  print("The names of the couple are " + husband_name + " and " + wife_name)
say_names_of_couple(husband_name, wife_name)
# Out:
# The names of the couple are Bill and Zelda
